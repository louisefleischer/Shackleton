# %%
#Working with the notebook is mostly relevant for plots
using PyPlot
using Plots

# %%
include("simulationv2.jl")
# Out:
# LoadError: LoadError: syntax: unexpected "="
# while loading C:\Users\pierr\OneDrive\Documents\[Stanford]\AA228 - DMU\Lander\Shackleton\fct_obsAndBel.jl, in expression starting on line 12
# while loading C:\Users\pierr\OneDrive\Documents\[Stanford]\AA228 - DMU\Lander\Shackleton\simulationv2.jl, in expression starting on line 3
#
# Stacktrace:
#  [1] include_from_node1(::String) at .\loading.jl:569
#  [2] include(::String) at .\sysimg.jl:14
#  [3] include_from_node1(::String) at .\loading.jl:569
#  [4] include(::String) at .\sysimg.jl:14
#  [5] include_string(::String, ::String) at .\loading.jl:515

# %%
hold(true)
PyPlot.plot(x_path'-.5,z_path'+.5,color="#FF0000")
PyPlot.bar(collect(1:MAP_SIZE)-1, true_map,color="#A4A4A4",align="edge",width=1,alpha=1)
println(" ")
PyPlot.grid("on")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002C910748>)

# %%
heatmap(U_init')
# Out:
# <img src="data:image/png;base64,..." />

# %%
pcolormesh(U_init')
colorbar()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003B421438>)
# PyObject <matplotlib.collections.QuadMesh object at 0x000000002D411780>
