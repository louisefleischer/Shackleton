# %%
#Working with the notebook is mostly relevant for plots
using PyPlot
using Plots

# %%
include("simulationv2.jl")
# Out:
# The lander has arrived at x=67 and z=23 in 77 iterations
# Measurements made : 100
# Safe landing!

# %%
hold(true)
PyPlot.plot(x_path'-.5,z_path'+.5,color="#FF0000")
PyPlot.bar(collect(1:MAP_SIZE)-1, true_map,color="#A4A4A4",align="edge",width=1,alpha=1)
println(" ")
PyPlot.grid("on")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003C146400>)

# %%
heatmap(U_init')
# Out:
# <img src="data:image/png;base64,..." />
