# %%
#Working with the notebook is mostly relevant for plots
using PyPlot
using Plots

# %%
include("simulationv2.jl")
# Out:
# LoadError: UndefVarError: max_height not defined
# while loading C:\Users\pierr\OneDrive\Documents\[Stanford]\AA228 - DMU\Lander\Shackleton\simulationv2.jl, in expression starting on line 9
#
# Stacktrace:
#  [1] include_from_node1(::String) at .\loading.jl:569
#  [2] include(::String) at .\sysimg.jl:14
#  [3] include_string(::String, ::String) at .\loading.jl:515

# %%
hold(true)
PyPlot.plot(x_path'-.5,z_path'+.5,color="#FF0000")
PyPlot.bar(collect(1:MAP_SIZE)-1, true_map,color="#A4A4A4",align="edge",width=1,alpha=1)
println(" ")
PyPlot.grid("on")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003B57F0F0>)

# %%
heatmap(U_init')
# Out:
# <img src="data:image/png;base64,..." />

# %%
pcolormesh(U_init')
colorbar()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003BEAE3C8>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x000000002D4B7550>

# %%
lander.x
# Out:
# 101
