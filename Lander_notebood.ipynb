# %%
#Working with the notebook is mostly relevant for plots
using PyPlot

# %%
include("simulationv2.jl")
# Out:
# The lander has arrived at x=39 and z=10 in 40 iterations
# Measurements made : 100
# Safe landing!

# %%
hold(true)
plot(x_path'-.5,z_path'+.5,color="#FF0000")
bar(collect(1:MAP_SIZE)-1, true_map,color="#A4A4A4",align="edge",width=1)
println("what a nice plot")
# Out:
# what a nice plot
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003AE73F28>)
